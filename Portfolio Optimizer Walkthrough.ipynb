# %% [markdown]
# # Portfolio Optimizer
#
# ## This notebook walks through the steps needed to create the payload used by the Portfolio Optimization service
#
# This notebook requires a tradable universe. The experimental version of the Portfolio Optimization service has a static data set for users to play with; a dynamic data set will be integrated in a future release. Note that much of the data in this sample set is _representative_ of actual data.
#
# Live, accurate data will be available upon the Beta release of the service. For now, the spreadsheet "Fidelity Universe Data_FINAL" contains all relevant information on the current sample data set.

# %% [markdown]
# ## Step 1 - Load in Data Set Details
#
# Load the file into DSX. Apparently there's a command that simply inserts the code into your notebook that converts the csv file to a pandas dataframe!

# %%
from io import StringIO
import requests
import json
import pandas as pd

##### ENTER DSX OBJECT STORE CREDENTIALS #####
dsx_id = ""
dsx_pw = ""

# @hidden_cell
# This function accesses a file in your Object Storage. The definition contains your credentials.
# You might want to remove those credentials before you share your notebook.
def get_object_storage_file_with_credentials_c0ad3ca445274f9d94984cea37d66ebd(container, filename):
    """This functions returns a StringIO object containing
    the file content from Bluemix Object Storage."""

    url1 = ''.join(['https://identity.open.softlayer.com', '/v3/auth/tokens'])
    data = {'auth': {'identity': {'methods': ['password'],
            'password': {'user': {'name': 'member_f8ee0f52dadee561e6fc64bc7a725c6edeb84230','domain': {'id': dsx_id},
            'password': dsx_pw}}}}}
    headers1 = {'Content-Type': 'application/json'}
    resp1 = requests.post(url=url1, data=json.dumps(data), headers=headers1)
    resp1_body = resp1.json()
    for e1 in resp1_body['token']['catalog']:
        if(e1['type']=='object-store'):
            for e2 in e1['endpoints']:
                        if(e2['interface']=='public'and e2['region']=='dallas'):
                            url2 = ''.join([e2['url'],'/', container, '/', filename])
    s_subject_token = resp1.headers['x-subject-token']
    headers2 = {'X-Auth-Token': s_subject_token, 'accept': 'application/json'}
    resp2 = requests.get(url=url2, headers=headers2)
    return StringIO(resp2.text)

universe_data = pd.read_csv(get_object_storage_file_with_credentials_c0ad3ca445274f9d94984cea37d66ebd('MarketDataExperience', 'Fidelity Universe Data_FINAL.csv'))
universe_data.head()

# %% [markdown]
# Create the Expected Returns and Standard Deviation file:

# %% [markdown]
# # Step 2 - Inputs: Holdings, Benchmarks, Objectives, and Preferences
#
# As with any optimization problem, there are a few things we need to determine before we get started:
# - **Holdings**: Where are we starting from? A blank slate? Or does the user have existing holdings?
# - **Benchmark**: If we're matching the properties of something, what are we matching?
# - **Objective**: What are we trying to do? Are we minimizing or maximizing some property? Or are we matching a target?
# - **Preferences**: What are the users unique preferences and constraints that we need to take into account when performing this calculation? Is there anything that can't be included? Do we need to have a specific weight at the end of our calculation?

# %%
import json

#Initiliaze the request
optimization = {
    "portfolios": [],
    "objectives": [],
    "constraints": []
}

# %% [markdown]
# ## Holdings
#
# First we need to decide if we're starting from scratch, or if the user already has a portfolio of assets. We only need to specify the ID of the asset (our data set that we loaded above uses ticker) and the quantity in # of units.
#
# We also need to define how much cash - in addition to the assets in the portfolio - the client wants to add to this analysis.
#
# We define this as an array of json objects:

# %%
##### PUT IN YOUR HOLDINGS HERE #####
Holdings = []
Holdings.append({"asset":"FDRXX","quantity":32000}) #Example of a holding

#Example cash infusion
Cash = 10000
#####################################

#Initilialize the 'tradeable universe' - note that position units should be populated where assets are held.
tradeable_universe = {
    "name": "Universe",
    "type":"root",
    "holdings":[]
}
for index, row in universe_data.iterrows():
    holding = [h for h in Holdings if h["asset"] == row["Ticker"]]
    if holding:
        tradeable_universe["holdings"].append(h)
    else:
        tradeable_universe["holdings"].append({"asset":row["Ticker"],"quantity":0})

optimization["portfolios"].append(tradeable_universe)
# Debug
#print json.dumps(optimization, indent=4, sort_keys=True)
#print("Holdings: " + str(Holdings))
#print("Cash: " + str(Cash))

# %% [markdown]
# ## Benchmark
#
# Next we need to pick a benchmark for our analysis. If we're simply optimizing to minimize variance/maximize return objectively, then this step can be skipped.
#
# Instead, in our analysis we assume that our advisor is recommending an "off-the-shelf" portfolio that meets our risk and return objectives that we want to use, with some caveats. Here we select that benchmark by assigning the name to the Benchmark variable below.
#
# Choices are:
# - Conservative (income-focused)
# - Moderate
# - Balanced
# - Growth
# - Aggressive Growth
# - Most Aggressive Growth
#
# Benchmark amount sets the total amount that the benchmark should add up to. This requirement may be depricated soon...

# %%
#ENTER DETAILS HERE
Benchmark_name = "Aggressive Growth"
Benchmark_amount = 50000 #Is this necessary?

#Assemble the benchmark portfolio using the above details:
Benchmark_col_name = "Benchmark - " + str(Benchmark_name)
benchmark = {
    "name": Benchmark_name,
    "type": "benchmark",
    "holdings": []
}
Benchmark_holdings = universe_data.filter(items=["Ticker","Last Close Price",Benchmark_col_name])[universe_data[Benchmark_col_name] <> 0]
for index,row in Benchmark_holdings.iterrows():
    #Determine weight of each asset
    shares = Benchmark_amount * row[Benchmark_col_name] / row["Last Close Price"]
    holding = {"asset":row["Ticker"],"quantity":shares}
    benchmark["holdings"].append(holding)
    
optimization["portfolios"].append(benchmark)
#Debug
#print(Benchmark_holdings)
print(benchmark)
# Out:
# {'holdings': [{'asset': 'FLVEX', 'quantity': 601.4434643143544}, {'asset': 'FVDFX', 'quantity': 179.0830945558739}, {'asset': 'FGRTX', 'quantity': 397.8779840848806}, {'asset': 'FSLEX', 'quantity': 199.2825827022718}, {'asset': 'FTHRX', 'quantity': 687.442713107241}, {'asset': 'FNCMX', 'quantity': 88.73639375295788}, {'asset': 'FSIIX', 'quantity': 242.89531212047606}], 'type': 'benchmark', 'name': 'Aggressive Growth'}

# %% [markdown]
# ## Objective
#
# Now we need to describe the overall mission of this analysis. We're going to hard-code this to be a minimization of variance of the returns of the portfolio - the standard [Markowitz approach](https://www.math.ust.hk/~maykwok/courses/ma362/07F/markowitz_JF.pdf).
#
# For this type of analysis, the only parameters we need to be concerned with are:
# - Whether or not we're trying to match the variance of the benchmark, or simply minimizing it objectively.
# - The time step, which is contingent on the data set (in our case it's 30 days)

# %%
optimization["objectives"] = [{
       "sense": "minimize",
       "measure": "variance",
       "attribute": "return",
       "portfolio": "Universe",
       "TargetPortfolio": Benchmark_name,
       "timestep": 30,
       "description": "minimize tracking error squared (variance of the difference between Universe portfolio and Benchmark returns) at time 30 days"
}]

#Debug 
print(optimization["objectives"])
# Out:
# [{'sense': 'minimize', 'description': 'minimize tracking error squared (variance of the difference between Universe portfolio and Benchmark returns) at time 30 days', 'timestep': 30, 'TargetPortfolio': 'Aggressive Growth', 'measure': 'variance', 'attribute': 'return', 'portfolio': 'Universe'}]

# %% [markdown]
# ## Preferences
#
# Now we get to the real meat of the analysis. This is where we can specify our custom constraints that will make this a _personalized_ analysis, resulting a portfolio with [as close to] identical properties as the benchmark portfolio, but with assets that meet the criteria specified below.
#
# There's a lot of flexibility in how one would specify these constraints, but for the sake of this walkthrough, we're identifying three main types:
#
# 1. __Filtering__: Ensuring that a certain type of investment is not present in the portfolio (e.g. "sin stocks", military investments)
# 2. __ESG and Socially Responsible Investing Requirements__: Determine a minimum threshold for types of companies one would want included in a portfolio (e.g. I want my portfolio's average Governance score to be "High")
# 3. __Investment Allocation__: Determine specific weight requirements of the portfolio (e.g. 70% bonds, 30% stocks)
#
# The user can also specify standard result requirements including:
# - Allow/Prevent short-selling (e.g. weights can or can't go negative)
# - Maximum allocation to any one security

# %%
##### CONSTRAINTS #####
#Uncomment the constraints you wish to apply:

#Filtering Constraints - "The final portfolio..."
Filtering_Constraints = []
#Filtering_Constraints.append("Has Tobacco")
#Filtering_Constraints.append("Has Alcohol")
#Filtering_Constraints.append("Has Gambling")
Filtering_Constraints.append("Has Military") #Ex) No military investments desired in the portfolio
#Filtering_Constraints.append("Has Fossil Fuels")
    
#ESG Constraints - Define both a field and an mean score desired (e.g. "Low","Average","High")
ESG_Constraints = []
#ESG_Constraints.append({"field":"Controversy","mean_score":"High"})
ESG_Constraints.append({"field":"Environmental","mean_score":"High"})
#ESG_Constraints.append({"field":"Governance","mean_score":"High"})
#ESG_Constraints.append({"field":"Social","mean_score":"High"})
#ESG_Constraints.append({"field":"Sustainability","mean_score":"High"})
                       
#Investment Allocation Constraints - I want to allocate [allocation]% of my portfoilio to be [value] identified by the [field] of the assets.
#inequality can be "greater-or-equal","less-or-equal" or "equal"
Allocation_Constraints = []
Allocation_Constraints.append({"field":"ActiveOrPassive","value":"Passive","allocation":.1,"inequality":"greater-or-equal"}) #Field values are "Active" or "Passive"
#Allocation_Constraints.append({"field":"Geography","value":"International","allocation":.1,"inequality":"less-or-equal"}) #Field values are "Domestic" or "International"
#Allocation_Constraints.append({"field":"Asset Class","value":"Equity","allocation":.1,"inequality":"equal"}) #Field values are "Equity","Corporate Bonds","Municipal Bonds","Mortages","Mixed","Money Market", or "Commodities"
#Allocation_Constraints.append({"field":"Sector","value":"Information Technology","allocation":.1,"inequality":"greater-or-equal"}) #Field values are..
#"Consumer Discretionary","Consumer Staples","Energy","Financials","Health Care","Industrials","Information Technology","Materials","Real Estate","Utilities","Commodity","Government", or "Diversified"

#Result requirements
AllowShortSales = False           #No short-selling
MaximumInvestmentWeight = .2      #20%
#MaximumNumberofPositions = 5     #Cardinality constraint on the portfolio
#MinimumNumberofPositions = 5     #Cardinality constraint on the portfolio

#Debug
print("Filtering Constraints: " + str(Filtering_Constraints))
print("ESG Constraints: " + str(ESG_Constraints))
print("Allocation Constraints: " + str(Allocation_Constraints))
# Out:
# Filtering Constraints: ['Has Military']
# ESG Constraints: [{'field': 'Environmental', 'mean_score': 'High'}]
# Allocation Constraints: [{'allocation': 0.1, 'field': 'ActiveOrPassive', 'inequality': 'greater-or-equal', 'value': 'Passive'}]

# %%
#FILTERING CONTRAINTS
#Add sub-portfolio (how the optimization algorithm knows which asset has which property)
for f in Filtering_Constraints:
    #initialize the subportfolio
    subportfolio = {
        "ParentPortfolio":"Universe",
        "name":f,
        "type":"subportfolio",
        "holdings":[]
    }
    
    #find all the assets that meet the criteria and add them to the subportfolio. Populate holdings quantity if available.
    assets = universe_data.filter(items=["Ticker",f])[universe_data[f] <> 0]
    for index,row in assets.iterrows():  
        holding = [h for h in Holdings if h["asset"] == row["Ticker"]]
        if holding:
            subportfolio["holdings"].append(h)
        else:
            subportfolio["holdings"].append({"asset":row["Ticker"],"quantity":0})

    #Add subportfolio to list
    optimization["portfolios"].append(subportfolio)          
            
    #Add constraint to list
    optimization["constraints"].append({
        "attribute":"weight",
        "portfolio":f,
        "InPortfolio":"Universe",
        "relation":"equal",
        "constant":0.0,
        "description":"Excluding all securities which have the property " + f + "."
    })
    
#Debug
print json.dumps(subportfolio, indent=4, sort_keys=True)
# Out:
# {
#     "ParentPortfolio": "Universe",
#     "holdings": [
#         {
#             "asset": "FLVEX",
#             "quantity": 0
#         },
#         {
#             "asset": "FVDFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSMVX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDVLX",
#             "quantity": 0
#         },
#         {
#             "asset": "FCPVX",
#             "quantity": 0
#         },
#         {
#             "asset": "FGRTX",
#             "quantity": 0
#         },
#         {
#             "asset": "FMEIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDCAX",
#             "quantity": 0
#         },
#         {
#             "asset": "FCNTX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDFFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FMILX",
#             "quantity": 0
#         },
#         {
#             "asset": "FBGRX",
#             "quantity": 0
#         },
#         {
#             "asset": "FEXPX",
#             "quantity": 0
#         },
#         {
#             "asset": "FOCPX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDSSX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDEGX",
#             "quantity": 0
#         },
#         {
#             "asset": "FLVCX",
#             "quantity": 0
#         },
#         {
#             "asset": "FIVFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FIGRX",
#             "quantity": 0
#         },
#         {
#             "asset": "FOSFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FISMX",
#             "quantity": 0
#         },
#         {
#             "asset": "FHKCX",
#             "quantity": 0
#         },
#         {
#             "asset": "FEMEX",
#             "quantity": 0
#         },
#         {
#             "asset": "FPBFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FJSCX",
#             "quantity": 0
#         },
#         {
#             "asset": "FEMKX",
#             "quantity": 0
#         },
#         {
#             "asset": "FNARX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSRBX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSPCX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSPHX",
#             "quantity": 0
#         },
#         {
#             "asset": "FBIOX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSAIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSLEX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSCGX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSPTX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDCPX",
#             "quantity": 0
#         },
#         {
#             "asset": "FBSOX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSAGX",
#             "quantity": 0
#         },
#         {
#             "asset": "FFGCX",
#             "quantity": 0
#         },
#         {
#             "asset": "FRXIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FIUIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FJRLX",
#             "quantity": 0
#         },
#         {
#             "asset": "FCSTX",
#             "quantity": 0
#         },
#         {
#             "asset": "FGOVX",
#             "quantity": 0
#         },
#         {
#             "asset": "FINPX",
#             "quantity": 0
#         },
#         {
#             "asset": "FAGIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FTHRX",
#             "quantity": 0
#         },
#         {
#             "asset": "FBNDX",
#             "quantity": 0
#         },
#         {
#             "asset": "FGBFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FOCFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FFTHX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDEEX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDKVX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSANX",
#             "quantity": 0
#         },
#         {
#             "asset": "FBALX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDYSX",
#             "quantity": 0
#         },
#         {
#             "asset": "FIRNX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSCKX",
#             "quantity": 0
#         },
#         {
#             "asset": "FENSX",
#             "quantity": 0
#         },
#         {
#             "asset": "FNCMX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSIIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FPMAX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSBIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSBAX",
#             "quantity": 0
#         },
#         {
#             "asset": "FLBIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSIYX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDRXX",
#             "quantity": 32000
#         },
#         {
#             "asset": "CX_US4642874659_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642875078_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642875987_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642876142_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642878049_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642882819_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642886877_NYQ",
#             "quantity": 0
#         }
#     ],
#     "name": "Has Military",
#     "type": "subportfolio"
# }

# %%
#ESG CONSTRAINTS
#Add sub-portfolio (how the optimization algorithm knows which asset has which property)
for e in ESG_Constraints:
    #initialize the subportfolio
    subportfolio = {
        "ParentPortfolio":"Universe",
        "name": e["mean_score"] + e["field"],
        "type":"subportfolio",
        "holdings":[]
    }
    
    #find all the assets that meet the criteria and add them to the subportfolio. Populate holdings quantity if available.
    assets = universe_data.filter(items=["Ticker",e["field"]])[universe_data[e["field"]] == e["mean_score"]]
    for index,row in assets.iterrows():  
        holding = [h for h in Holdings if h["asset"] == row["Ticker"]]
        if holding:
            subportfolio["holdings"].append(h)
        else:
            subportfolio["holdings"].append({"asset":row["Ticker"],"quantity":0})

    #Add subportfolio to list
    optimization["portfolios"].append(subportfolio)          
            
    #Add constraint to list
    optimization["constraints"].append({
        "attribute":"weight",
        "portfolio":e["mean_score"] + e["field"],
        "InPortfolio":"Universe",
        "relation":"greater-or-equal",
        "constant":.5,
        "description":"Creating an average " + e["field"] + " score of " + e["mean_score"] + "."
    })
    
#Debug
print json.dumps(subportfolio, indent=4, sort_keys=True)
# Out:
# {
#     "ParentPortfolio": "Universe",
#     "holdings": [
#         {
#             "asset": "FBCVX",
#             "quantity": 0
#         },
#         {
#             "asset": "FVDFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FLPSX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSMVX",
#             "quantity": 0
#         },
#         {
#             "asset": "FCPVX",
#             "quantity": 0
#         },
#         {
#             "asset": "FEQTX",
#             "quantity": 0
#         },
#         {
#             "asset": "FLCEX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDGRX",
#             "quantity": 0
#         },
#         {
#             "asset": "FOCPX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDEGX",
#             "quantity": 0
#         },
#         {
#             "asset": "FIENX",
#             "quantity": 0
#         },
#         {
#             "asset": "FIVFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FIGFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FHKCX",
#             "quantity": 0
#         },
#         {
#             "asset": "FICDX",
#             "quantity": 0
#         },
#         {
#             "asset": "FJPNX",
#             "quantity": 0
#         },
#         {
#             "asset": "FEMKX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSAVX",
#             "quantity": 0
#         },
#         {
#             "asset": "FBMPX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSPHX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSAIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDCPX",
#             "quantity": 0
#         },
#         {
#             "asset": "FFGCX",
#             "quantity": 0
#         },
#         {
#             "asset": "FCRDX",
#             "quantity": 0
#         },
#         {
#             "asset": "FMNDX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSAHX",
#             "quantity": 0
#         },
#         {
#             "asset": "FCSTX",
#             "quantity": 0
#         },
#         {
#             "asset": "FGMNX",
#             "quantity": 0
#         },
#         {
#             "asset": "FTBFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FAGIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FTHRX",
#             "quantity": 0
#         },
#         {
#             "asset": "FNMIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FHIFX",
#             "quantity": 0
#         },
#         {
#             "asset": "FFTHX",
#             "quantity": 0
#         },
#         {
#             "asset": "FDEEX",
#             "quantity": 0
#         },
#         {
#             "asset": "FFFAX",
#             "quantity": 0
#         },
#         {
#             "asset": "FBALX",
#             "quantity": 0
#         },
#         {
#             "asset": "FIRNX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSCKX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSIIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSGUX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSBIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FIBIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSIYX",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US03232PAD06_USD",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US0533321024_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US1696561059_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642871762_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642872000_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642874402_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642874576_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642884146_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642885135_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US4642886463_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US46434G1031_NYQ",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US912810EJ35_USD",
#             "quantity": 0
#         },
#         {
#             "asset": "CX_US912810PX00_USD",
#             "quantity": 0
#         }
#     ],
#     "name": "HighEnvironmental",
#     "type": "subportfolio"
# }

# %%
#ALLOCATION CONSTRAINTS
#Add sub-portfolio (how the optimization algorithm knows which asset has which property)
for a in Allocation_Constraints:
    #initialize the subportfolio
    subportfolio = {
        "ParentPortfolio":"Universe",
        "name": a["value"],
        "type":"subportfolio",
        "holdings":[]
    }
    
    #find all the assets that meet the criteria and add them to the subportfolio. Populate holdings quantity if available.
    assets = universe_data.filter(items=["Ticker",a["field"]])[universe_data[a["field"]] == a["value"]]
    for index,row in assets.iterrows():  
        holding = [h for h in Holdings if h["asset"] == row["Ticker"]]
        if holding:
            subportfolio["holdings"].append(h)
        else:
            subportfolio["holdings"].append({"asset":row["Ticker"],"quantity":0})

    #Add subportfolio to list
    optimization["portfolios"].append(subportfolio)          
            
    #Add constraint to list
    optimization["constraints"].append({
        "attribute":"weight",
        "portfolio":a["value"],
        "InPortfolio":"Universe",
        "relation":a["inequality"],
        "constant":a["allocation"],
        "description":"Weight of " + a["value"] + " in the portfolio should be " + a["inequality"] + " to " + str(a["allocation"]) + "."
    })
    
#Debug
print json.dumps(subportfolio, indent=4, sort_keys=True)
# Out:
# {
#     "ParentPortfolio": "Universe",
#     "holdings": [
#         {
#             "asset": "FSCKX",
#             "quantity": 0
#         },
#         {
#             "asset": "FENSX",
#             "quantity": 0
#         },
#         {
#             "asset": "FNCMX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSIIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSGUX",
#             "quantity": 0
#         },
#         {
#             "asset": "FPEMX",
#             "quantity": 0
#         },
#         {
#             "asset": "FPMAX",
#             "quantity": 0
#         },
#         {
#             "asset": "FFNOX",
#             "quantity": 0
#         },
#         {
#             "asset": "FBIDX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSBIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSBAX",
#             "quantity": 0
#         },
#         {
#             "asset": "FIBIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FLBIX",
#             "quantity": 0
#         },
#         {
#             "asset": "FSIYX",
#             "quantity": 0
#         }
#     ],
#     "name": "Passive",
#     "type": "subportfolio"
# }

# %%
#RESULT REQUIREMENTS

#Short Sale Restriction
try:
    if AllowShortSales == False:
        optimization["constraints"].append({
           "attribute":"weight",
           "relation":"greater-or-equal",
           "members":"Universe",
           "constant":0,
           "description":"no short-sales for assets in Universe portfolio" 
        })
except:
    print("Short sales allowed")

#Maximum individual investment weight
try:
    optimization["constraints"].append({
       "attribute":"weight",
       "relation":"less-or-equal",
       "members":"Universe",
       "constant":MaximumInvestmentWeight,
       "description":"Weight of each asset from the Universe portfolio does not exceed " + str(MaximumInvestmentWeight*100) + "%."
    })
except:
    print("No maximum investment weight.")

#Maximum number of trades/positions
try:
    optimization["constraints"].append({
        "attribute": "count", 
        "relation": "less-or-equal", 
        "constant": MaximumNumberofPositions })
except:
    print("No maximum number of positions.")

#Minimum number of trades/positions
try:
    optimization["constraints"].append({
        "attribute": "count", 
        "relation": "greater-or-equal", 
        "constant": MinimumNumberofPositions })
except:
    print("No minimum number of positions.")

#Cash infusions
try:
    optimization["constraints"].append({
        "attribute:": "value",
        "portfolio": "Universe",
        "cashadjust": Cash,
        "description": "cash inflow of " + str(Cash) +" monetary units to the Universe portfolio"})
except:
    print("No cash infusions.")
    
# Debug
print json.dumps(optimization["constraints"], indent=4, sort_keys=True)
# Out:
# No maximum number of positions.
# No minimum number of positions.
# [
#     {
#         "InPortfolio": "Universe",
#         "attribute": "weight",
#         "constant": 0.0,
#         "description": "Excluding all securities which have the property Has Military.",
#         "portfolio": "Has Military",
#         "relation": "equal"
#     },
#     {
#         "InPortfolio": "Universe",
#         "attribute": "weight",
#         "constant": 0.5,
#         "description": "Creating an average Environmental score of High.",
#         "portfolio": "HighEnvironmental",
#         "relation": "greater-or-equal"
#     },
#     {
#         "InPortfolio": "Universe",
#         "attribute": "weight",
#         "constant": 0.1,
#         "description": "Weight of Passive in the portfolio should be greater-or-equal to 0.1.",
#         "portfolio": "Passive",
#         "relation": "greater-or-equal"
#     },
#     {
#         "attribute": "weight",
#         "constant": 0,
#         "description": "no short-sales for assets in Universe portfolio",
#         "members": "Universe",
#         "relation": "greater-or-equal"
#     },
#     {
#         "attribute": "weight",
#         "constant": 0.2,
#         "description": "Weight of each asset from the Universe portfolio does not exceed 20.0%.",
#         "members": "Universe",
#         "relation": "less-or-equal"
#     },
#     {
#         "attribute:": "value",
#         "cashadjust": 10000,
#         "description": "cash inflow of 10000 monetary units to the Universe portfolio",
#         "portfolio": "Universe"
#     }
# ]

# %% [markdown]
# ## The Assembled Request:
#
# We've assembled our payload! Below is what it looks like:

# %%
print json.dumps(optimization, indent=4, sort_keys=True)
# Out:
# {
#     "constraints": [
#         {
#             "InPortfolio": "Universe",
#             "attribute": "weight",
#             "constant": 0.0,
#             "description": "Excluding all securities which have the property Has Military.",
#             "portfolio": "Has Military",
#             "relation": "equal"
#         },
#         {
#             "InPortfolio": "Universe",
#             "attribute": "weight",
#             "constant": 0.5,
#             "description": "Creating an average Environmental score of High.",
#             "portfolio": "HighEnvironmental",
#             "relation": "greater-or-equal"
#         },
#         {
#             "InPortfolio": "Universe",
#             "attribute": "weight",
#             "constant": 0.1,
#             "description": "Weight of Passive in the portfolio should be greater-or-equal to 0.1.",
#             "portfolio": "Passive",
#             "relation": "greater-or-equal"
#         },
#         {
#             "attribute": "weight",
#             "constant": 0,
#             "description": "no short-sales for assets in Universe portfolio",
#             "members": "Universe",
#             "relation": "greater-or-equal"
#         },
#         {
#             "attribute": "weight",
#             "constant": 0.2,
#             "description": "Weight of each asset from the Universe portfolio does not exceed 20.0%.",
#             "members": "Universe",
#             "relation": "less-or-equal"
#         },
#         {
#             "attribute:": "value",
#             "cashadjust": 10000,
#             "description": "cash inflow of 10000 monetary units to the Universe portfolio",
#             "portfolio": "Universe"
#         }
#     ],
#     "objectives": [
#         {
#             "TargetPortfolio": "Aggressive Growth",
#             "attribute": "return",
#             "description": "minimize tracking error squared (variance of the difference between Universe portfolio and Benchmark returns) at time 30 days",
#             "measure": "variance",
#             "portfolio": "Universe",
#             "sense": "minimize",
#             "timestep": 30
#         }
#     ],
#     "portfolios": [
#         {
#             "holdings": [
#                 {
#                     "asset": "FBCVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLVEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FVDFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLPSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSMVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDVLX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCPVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FEQTX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FEQIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGRIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDEQX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLCEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLCSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGRTX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FMEIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCPEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDSCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDCAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCNTX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDFFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FMAGX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FMILX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBGRX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FEXPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFIDX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDSVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDGRX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FOCPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDSSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDEGX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FMCSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSSMX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCPGX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLVCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FARNX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIENX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIVFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIGRX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDIVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FOSFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIGFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIVLX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FISMX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSCOX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FHKCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FEMEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIEUX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLATX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FNORX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FPBFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FICDX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FJPNX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FJSCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGILX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FEMKX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSAVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDLSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBMPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDFAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSNGX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FNARX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIDSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSRBX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSPCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSPHX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBIOX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FPHAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCYIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSAIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSLEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSCGX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSPTX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDCPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBSOX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSCHX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSAGX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFGCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FRXIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIREX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIUIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCONX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCRDX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FMNDX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FJRLX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSAHX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFXSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCSTX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFRHX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCBFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FMSFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGMNX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGOVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FINPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FTBFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FAGIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FTHRX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBNDX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGBFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FNMIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGHNX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FHIFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FHIGX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLTMX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FMCFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FOCFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFTHX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDEEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDKVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFFAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFANX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSANX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBALX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGBLX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDYSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIRNX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSCKX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FENSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FNCMX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSIIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSGUX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FPEMX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FPMAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFNOX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBIDX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSBIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSBAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIBIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLBIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSIYX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDRXX",
#                     "quantity": 32000
#                 },
#                 {
#                     "asset": "CX_IE00BY7QL619_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US02079KAA51_USD",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US031162BG42_USD",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US031162BK53_USD",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US03232PAD06_USD",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US0533321024_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US0584981064_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US1696561059_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US1912161007_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US29379VAY92_USD",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US30231GAN25_USD",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US46120E6023_NSQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642851053_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642871762_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642872000_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642872422_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642874329_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642874402_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642874576_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642874659_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642875078_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642875987_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642876142_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642878049_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642882819_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642884146_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642885135_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642885887_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642886463_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642886612_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642886877_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US46434G1031_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4878361082_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US5486611073_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US56585AAG76_USD",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US651639AN69_USD",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US70450Y1038_NSQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US9100471096_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US912810EJ35_USD",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US912810PX00_USD",
#                     "quantity": 0
#                 }
#             ],
#             "name": "Universe",
#             "type": "root"
#         },
#         {
#             "holdings": [
#                 {
#                     "asset": "FLVEX",
#                     "quantity": 601.4434643143544
#                 },
#                 {
#                     "asset": "FVDFX",
#                     "quantity": 179.0830945558739
#                 },
#                 {
#                     "asset": "FGRTX",
#                     "quantity": 397.8779840848806
#                 },
#                 {
#                     "asset": "FSLEX",
#                     "quantity": 199.2825827022718
#                 },
#                 {
#                     "asset": "FTHRX",
#                     "quantity": 687.442713107241
#                 },
#                 {
#                     "asset": "FNCMX",
#                     "quantity": 88.73639375295788
#                 },
#                 {
#                     "asset": "FSIIX",
#                     "quantity": 242.89531212047606
#                 }
#             ],
#             "name": "Aggressive Growth",
#             "type": "benchmark"
#         },
#         {
#             "ParentPortfolio": "Universe",
#             "holdings": [
#                 {
#                     "asset": "FLVEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FVDFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSMVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDVLX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCPVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGRTX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FMEIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDCAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCNTX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDFFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FMILX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBGRX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FEXPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FOCPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDSSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDEGX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLVCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIVFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIGRX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FOSFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FISMX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FHKCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FEMEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FPBFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FJSCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FEMKX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FNARX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSRBX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSPCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSPHX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBIOX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSAIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSLEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSCGX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSPTX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDCPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBSOX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSAGX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFGCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FRXIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIUIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FJRLX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCSTX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGOVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FINPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FAGIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FTHRX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBNDX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGBFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FOCFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFTHX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDEEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDKVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSANX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBALX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDYSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIRNX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSCKX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FENSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FNCMX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSIIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FPMAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSBIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSBAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLBIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSIYX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDRXX",
#                     "quantity": 32000
#                 },
#                 {
#                     "asset": "CX_US4642874659_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642875078_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642875987_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642876142_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642878049_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642882819_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642886877_NYQ",
#                     "quantity": 0
#                 }
#             ],
#             "name": "Has Military",
#             "type": "subportfolio"
#         },
#         {
#             "ParentPortfolio": "Universe",
#             "holdings": [
#                 {
#                     "asset": "FBCVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FVDFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLPSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSMVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCPVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FEQTX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLCEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDGRX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FOCPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDEGX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIENX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIVFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIGFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FHKCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FICDX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FJPNX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FEMKX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSAVX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBMPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSPHX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSAIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDCPX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFGCX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCRDX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FMNDX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSAHX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FCSTX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FGMNX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FTBFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FAGIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FTHRX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FNMIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FHIFX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFTHX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FDEEX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFFAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBALX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIRNX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSCKX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSIIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSGUX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSBIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIBIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSIYX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US03232PAD06_USD",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US0533321024_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US1696561059_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642871762_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642872000_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642874402_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642874576_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642884146_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642885135_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US4642886463_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US46434G1031_NYQ",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US912810EJ35_USD",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "CX_US912810PX00_USD",
#                     "quantity": 0
#                 }
#             ],
#             "name": "HighEnvironmental",
#             "type": "subportfolio"
#         },
#         {
#             "ParentPortfolio": "Universe",
#             "holdings": [
#                 {
#                     "asset": "FSCKX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FENSX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FNCMX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSIIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSGUX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FPEMX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FPMAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FFNOX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FBIDX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSBIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSBAX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FIBIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FLBIX",
#                     "quantity": 0
#                 },
#                 {
#                     "asset": "FSIYX",
#                     "quantity": 0
#                 }
#             ],
#             "name": "Passive",
#             "type": "subportfolio"
#         }
#     ]
# }

# %% [markdown]
# # Step 3 - Submit the Request
#
# Now that we have the payload assembled, we issue a [requests](http://docs.python-requests.org/en/master/) command to the Portfolio Optimization service running on the cloud. You'll want to provision your own copy of the application [which can be done here on Bluemix](https://console.bluemix.net/catalog/services/portfolio-optimization?env_id=ibm:yp:us-south). Fill in your uri and API credentials below before issuing the command.

# %%
##### ENTER YOUR PORTFOLIO OPTIMZIATION SERVICE CREDENTIALS #####
uri = "fss-analytics.mybluemix.net"
api_key = ""
#################################################################

url = "https://" + uri + "/api/v1/optimization/portfolio/construct"
headers = {'content-type': 'application/json', 'accept': 'application/json', 'X-IBM-Access-Token': api_key}
data = json.dumps(optimization)

import requests
r = requests.post(url,data=data,headers=headers)

print(r.text)
# Out:
# {
#  "Holdings": [
#   {
#    "Asset": "FBCVX",
#    "Quantity": 0,
#    "OptimizedTrade": 8.52802862476909,
#    "OptimizedQuantity": 8.52802862476909
#   },
#   {
#    "Asset": "FLVEX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FVDFX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FLPSX",
#    "Quantity": 0,
#    "OptimizedTrade": 4.19366728603124,
#    "OptimizedQuantity": 4.19366728603124
#   },
#   {
#    "Asset": "FSMVX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDVLX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FCPVX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FEQTX",
#    "Quantity": 0,
#    "OptimizedTrade": 1.18725515567421,
#    "OptimizedQuantity": 1.18725515567421
#   },
#   {
#    "Asset": "FEQIX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FGRIX",
#    "Quantity": 0,
#    "OptimizedTrade": 29.5366532037034,
#    "OptimizedQuantity": 29.5366532037034
#   },
#   {
#    "Asset": "FDEQX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FLCEX",
#    "Quantity": 0,
#    "OptimizedTrade": 0.809691929125045,
#    "OptimizedQuantity": 0.809691929125045
#   },
#   {
#    "Asset": "FLCSX",
#    "Quantity": 0,
#    "OptimizedTrade": 32.8861083474232,
#    "OptimizedQuantity": 32.8861083474232
#   },
#   {
#    "Asset": "FGRTX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FMEIX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FCPEX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDSCX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDCAX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FCNTX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDFFX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FMAGX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FMILX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FBGRX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FEXPX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FFIDX",
#    "Quantity": 0,
#    "OptimizedTrade": 10.8622383273405,
#    "OptimizedQuantity": 10.8622383273405
#   },
#   {
#    "Asset": "FDSVX",
#    "Quantity": 0,
#    "OptimizedTrade": 8.15067992285397,
#    "OptimizedQuantity": 8.15067992285397
#   },
#   {
#    "Asset": "FDGRX",
#    "Quantity": 0,
#    "OptimizedTrade": 13.0185175513786,
#    "OptimizedQuantity": 13.0185175513786
#   },
#   {
#    "Asset": "FOCPX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDSSX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDEGX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FMCSX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSSMX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FCPGX",
#    "Quantity": 0,
#    "OptimizedTrade": 2.77149672569649,
#    "OptimizedQuantity": 2.77149672569649
#   },
#   {
#    "Asset": "FLVCX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FARNX",
#    "Quantity": 0,
#    "OptimizedTrade": 25.5485083784375,
#    "OptimizedQuantity": 25.5485083784375
#   },
#   {
#    "Asset": "FIENX",
#    "Quantity": 0,
#    "OptimizedTrade": 22.7034109609636,
#    "OptimizedQuantity": 22.7034109609636
#   },
#   {
#    "Asset": "FIVFX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FIGRX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDIVX",
#    "Quantity": 0,
#    "OptimizedTrade": 63.2344558563362,
#    "OptimizedQuantity": 63.2344558563362
#   },
#   {
#    "Asset": "FOSFX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FIGFX",
#    "Quantity": 0,
#    "OptimizedTrade": 15.824677749481,
#    "OptimizedQuantity": 15.824677749481
#   },
#   {
#    "Asset": "FIVLX",
#    "Quantity": 0,
#    "OptimizedTrade": 21.4171865483791,
#    "OptimizedQuantity": 21.4171865483791
#   },
#   {
#    "Asset": "FISMX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSCOX",
#    "Quantity": 0,
#    "OptimizedTrade": 8.86976805259214,
#    "OptimizedQuantity": 8.86976805259214
#   },
#   {
#    "Asset": "FHKCX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FEMEX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FIEUX",
#    "Quantity": 0,
#    "OptimizedTrade": 34.3907444068063,
#    "OptimizedQuantity": 34.3907444068063
#   },
#   {
#    "Asset": "FLATX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FNORX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FPBFX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FICDX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FJPNX",
#    "Quantity": 0,
#    "OptimizedTrade": 42.8984939330449,
#    "OptimizedQuantity": 42.8984939330449
#   },
#   {
#    "Asset": "FJSCX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FGILX",
#    "Quantity": 0,
#    "OptimizedTrade": 7.5086941348892,
#    "OptimizedQuantity": 7.5086941348892
#   },
#   {
#    "Asset": "FEMKX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSAVX",
#    "Quantity": 0,
#    "OptimizedTrade": 49.5419719370515,
#    "OptimizedQuantity": 49.5419719370515
#   },
#   {
#    "Asset": "FDLSX",
#    "Quantity": 0,
#    "OptimizedTrade": 5.71668106627006,
#    "OptimizedQuantity": 5.71668106627006
#   },
#   {
#    "Asset": "FBMPX",
#    "Quantity": 0,
#    "OptimizedTrade": 12.3739275274531,
#    "OptimizedQuantity": 12.3739275274531
#   },
#   {
#    "Asset": "FDFAX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSNGX",
#    "Quantity": 0,
#    "OptimizedTrade": 27.5834774180015,
#    "OptimizedQuantity": 27.5834774180015
#   },
#   {
#    "Asset": "FNARX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FIDSX",
#    "Quantity": 0,
#    "OptimizedTrade": 42.0605757027058,
#    "OptimizedQuantity": 42.0605757027058
#   },
#   {
#    "Asset": "FSRBX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSPCX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSPHX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FBIOX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FPHAX",
#    "Quantity": 0,
#    "OptimizedTrade": 36.7663655062497,
#    "OptimizedQuantity": 36.7663655062497
#   },
#   {
#    "Asset": "FCYIX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSAIX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSLEX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSCGX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSPTX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDCPX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FBSOX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSCHX",
#    "Quantity": 0,
#    "OptimizedTrade": 3.58403649039186,
#    "OptimizedQuantity": 3.58403649039186
#   },
#   {
#    "Asset": "FSAGX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FFGCX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FRXIX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FIREX",
#    "Quantity": 0,
#    "OptimizedTrade": 11.3695340219956,
#    "OptimizedQuantity": 11.3695340219956
#   },
#   {
#    "Asset": "FIUIX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FCONX",
#    "Quantity": 0,
#    "OptimizedTrade": 2.09561879077714,
#    "OptimizedQuantity": 2.09561879077714
#   },
#   {
#    "Asset": "FCRDX",
#    "Quantity": 0,
#    "OptimizedTrade": 2.12835620182678,
#    "OptimizedQuantity": 2.12835620182678
#   },
#   {
#    "Asset": "FMNDX",
#    "Quantity": 0,
#    "OptimizedTrade": 2.12835620182678,
#    "OptimizedQuantity": 2.12835620182678
#   },
#   {
#    "Asset": "FJRLX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSAHX",
#    "Quantity": 0,
#    "OptimizedTrade": 7.57450734603391,
#    "OptimizedQuantity": 7.57450734603391
#   },
#   {
#    "Asset": "FFXSX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FCSTX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FFRHX",
#    "Quantity": 0,
#    "OptimizedTrade": 6.20735543270655,
#    "OptimizedQuantity": 6.20735543270655
#   },
#   {
#    "Asset": "FCBFX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FMSFX",
#    "Quantity": 0,
#    "OptimizedTrade": 0.453302491076815,
#    "OptimizedQuantity": 0.453302491076815
#   },
#   {
#    "Asset": "FGMNX",
#    "Quantity": 0,
#    "OptimizedTrade": 2.14566311362957,
#    "OptimizedQuantity": 2.14566311362957
#   },
#   {
#    "Asset": "FGOVX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FINPX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FTBFX",
#    "Quantity": 0,
#    "OptimizedTrade": 0.101934339674873,
#    "OptimizedQuantity": 0.101934339674873
#   },
#   {
#    "Asset": "FAGIX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FTHRX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FBNDX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FGBFX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FNMIX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FGHNX",
#    "Quantity": 0,
#    "OptimizedTrade": 4.33960493487698,
#    "OptimizedQuantity": 4.33960493487698
#   },
#   {
#    "Asset": "FHIFX",
#    "Quantity": 0,
#    "OptimizedTrade": 6.45843911679147,
#    "OptimizedQuantity": 6.45843911679147
#   },
#   {
#    "Asset": "FHIGX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FLTMX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FMCFX",
#    "Quantity": 0,
#    "OptimizedTrade": 1.6964331531298,
#    "OptimizedQuantity": 1.6964331531298
#   },
#   {
#    "Asset": "FOCFX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FFTHX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDEEX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDKVX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FFFAX",
#    "Quantity": 0,
#    "OptimizedTrade": 1.04683932210016,
#    "OptimizedQuantity": 1.04683932210016
#   },
#   {
#    "Asset": "FFANX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSANX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FBALX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FGBLX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDYSX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FIRNX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSCKX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FENSX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FNCMX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSIIX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSGUX",
#    "Quantity": 0,
#    "OptimizedTrade": 40.8370518341076,
#    "OptimizedQuantity": 40.8370518341076
#   },
#   {
#    "Asset": "FPEMX",
#    "Quantity": 0,
#    "OptimizedTrade": 17.8881038872257,
#    "OptimizedQuantity": 17.8881038872257
#   },
#   {
#    "Asset": "FPMAX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FFNOX",
#    "Quantity": 0,
#    "OptimizedTrade": 76.9473918032064,
#    "OptimizedQuantity": 76.9473918032064
#   },
#   {
#    "Asset": "FBIDX",
#    "Quantity": 0,
#    "OptimizedTrade": 14.0089231783781,
#    "OptimizedQuantity": 14.0089231783781
#   },
#   {
#    "Asset": "FSBIX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSBAX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FIBIX",
#    "Quantity": 0,
#    "OptimizedTrade": 7.9731154668696,
#    "OptimizedQuantity": 7.9731154668696
#   },
#   {
#    "Asset": "FLBIX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FSIYX",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "FDRXX",
#    "Quantity": 32000,
#    "OptimizedTrade": -32000,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_IE00BY7QL619_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0.0969932602800344,
#    "OptimizedQuantity": 0.0969932602800344
#   },
#   {
#    "Asset": "CX_US02079KAA51_USD",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US031162BG42_USD",
#    "Quantity": 0,
#    "OptimizedTrade": 0.225245248391056,
#    "OptimizedQuantity": 0.225245248391056
#   },
#   {
#    "Asset": "CX_US031162BK53_USD",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US03232PAD06_USD",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US0533321024_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 1.43047633674904,
#    "OptimizedQuantity": 1.43047633674904
#   },
#   {
#    "Asset": "CX_US0584981064_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 8.74280625928863,
#    "OptimizedQuantity": 8.74280625928863
#   },
#   {
#    "Asset": "CX_US1696561059_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US1912161007_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US29379VAY92_USD",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US30231GAN25_USD",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US46120E6023_NSQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0.0196475015947102,
#    "OptimizedQuantity": 0.0196475015947102
#   },
#   {
#    "Asset": "CX_US4642851053_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642871762_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642872000_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 31.8623157043932,
#    "OptimizedQuantity": 31.8623157043932
#   },
#   {
#    "Asset": "CX_US4642872422_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642874329_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642874402_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642874576_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 11.8169017173986,
#    "OptimizedQuantity": 11.8169017173986
#   },
#   {
#    "Asset": "CX_US4642874659_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642875078_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642875987_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642876142_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642878049_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642882819_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642884146_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 6.07671956627222,
#    "OptimizedQuantity": 6.07671956627222
#   },
#   {
#    "Asset": "CX_US4642885135_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 19.9083904421932,
#    "OptimizedQuantity": 19.9083904421932
#   },
#   {
#    "Asset": "CX_US4642885887_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 4.27028326182949,
#    "OptimizedQuantity": 4.27028326182949
#   },
#   {
#    "Asset": "CX_US4642886463_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 10.7344366854026,
#    "OptimizedQuantity": 10.7344366854026
#   },
#   {
#    "Asset": "CX_US4642886612_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US4642886877_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US46434G1031_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 12.0269908179209,
#    "OptimizedQuantity": 12.0269908179209
#   },
#   {
#    "Asset": "CX_US4878361082_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 3.37466929480565,
#    "OptimizedQuantity": 3.37466929480565
#   },
#   {
#    "Asset": "CX_US5486611073_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US56585AAG76_USD",
#    "Quantity": 0,
#    "OptimizedTrade": 0.165142991063858,
#    "OptimizedQuantity": 0.165142991063858
#   },
#   {
#    "Asset": "CX_US651639AN69_USD",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US70450Y1038_NSQ",
#    "Quantity": 0,
#    "OptimizedTrade": 18.1736550550222,
#    "OptimizedQuantity": 18.1736550550222
#   },
#   {
#    "Asset": "CX_US9100471096_NYQ",
#    "Quantity": 0,
#    "OptimizedTrade": 2.09756210798839,
#    "OptimizedQuantity": 2.09756210798839
#   },
#   {
#    "Asset": "CX_US912810EJ35_USD",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   },
#   {
#    "Asset": "CX_US912810PX00_USD",
#    "Quantity": 0,
#    "OptimizedTrade": 0,
#    "OptimizedQuantity": 0
#   }
#  ],
#  "Metadata": {
#   "Status": "Optimal",
#   "Message": "Diagonal elements have been adjusted by 1e-10:   Optimal",
#   "StatusCode": 1,
#   "ObjectiveValue": 0.00000165165998864848,
#   "TransactionID": "ba6e3717-8d7e-4836-894e-50fde71ea432",
#   "RequestStartTimestamp": "2017-08-18T12-44-47.888587331-UTC",
#   "RequestEndTimestamp": "2017-08-18T12-44-48.179487286-UTC"
#  },
#  "Performance": {
#   "Algorithm": "Dual",
#   "Threads": 2,
#   "Time": 0
#  }
# }

# %% [markdown]
# # Step 4 - Viewing your Results
#
# So let's take a look at the results of our optimization calculation:

# %%
import pixiedust
pixiedust.installPackage("graphframes:graphframes:0.1.0-spark1.6")

#Initialize Portfolio and field names
new_portfolio = []
fields = ["Name","Last Close Price"]

#Gather fields
for f in Filtering_Constraints:
    fields.append(f)
for e in ESG_Constraints:
    fields.append(e["field"])
#for a in Allocation_Constraints:
 #   fields.append(a["field"])
    
#Assemble the data frame
for i in json.loads(r.text)["Holdings"]:
    if i["OptimizedQuantity"] != 0:
        security_data = universe_data.filter(items=fields)[universe_data["Ticker"] == i["Asset"]]
        security_data = security_data.values.tolist()[0]
        security_data.append(i["OptimizedQuantity"] * security_data[1])
        total_data = (str(i["Asset"]),float(i["OptimizedQuantity"])) + tuple(security_data)
        new_portfolio.append(total_data)
        
fields = ["Ticker","Quantity"]+fields+["Total Value"]
    
#PixieDust Visualization
sqlContext=SQLContext(sc)
d1 = sqlContext.createDataFrame(new_portfolio,fields)
display(d1)

#Debug
#print(fields)
#print(new_portfolio)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;95b69afd&quot;, &quot;command&quot;: &quot;display(d1,cell_id=&apos;472933BD8A74434F94DBB1B35AB22528&apos;,nostore_pixiedust=&apos;true&apos;,handlerId=&apos;dataframe&apos;,nostore_cw=&apos;1350&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;options&quot;: {&quot;cell_id&quot;: &quot;472933BD8A74434F94DBB1B35AB22528&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;nostore_cw&quot;: &quot;1350&quot;, &quot;handlerId&quot;: &quot;dataframe&quot;, &quot;nostore_bokeh&quot;: &quot;false&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;showchrome&quot;: &quot;true&quot;}}">
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-95b69afd" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#   <div id="pixiedust-output-wrapper-95b69afd" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menu95b69afd-dataframe" title="DataFrame Table">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menu95b69afd-dataframe').on('click',
#
#
# function() {
#     function getTargetNode(){
#         var n = $('#' + 'wrapperHTML95b69afd');
#         if (n.length == 0 ){
#             n = $('#wrapperHTML95b69afd');
#         }
#         return n;
#     }
#     cellId = typeof cellId === "undefined" ? "" : cellId;
#     var curCell=IPython.notebook.get_cells().filter(function(cell){
#         return cell.cell_id=="472933BD8A74434F94DBB1B35AB22528".replace("cellId",cellId);
#     });
#     curCell=curCell.length>0?curCell[0]:null;
#     console.log("curCell",curCell);
#     var startWallToWall;
#     //Resend the display command
#     var callbacks = {
#         shell : {
#             payload : {
#                 set_next_input : function(payload){
#                     if (curCell){
#                         curCell._handle_set_next_input(payload);
#                     }
#                 }
#             }
#         },
#         iopub:{
#             output:function(msg){
#                 console.log("msg", msg);
#                 if (false){
#                     curCell.output_area.clear_output(false, true);
#                     curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                     return;
#                 }
#                 var msg_type=msg.header.msg_type;
#                 var content = msg.content;
#                 var executionTime = $("#execution95b69afd");
#                 if(msg_type==="stream"){
#                     getTargetNode().html(content.text);
#                 }else if (msg_type==="display_data" || msg_type==="execute_result"){
#                     var html=null;
#                     if (!!content.data["text/html"]){
#                         html=content.data["text/html"];
#                     }else if (!!content.data["image/png"]){
#                         html=html||"";
#                         html+="<img src='data:image/png;base64," +content.data["image/png"]+"'></img>";
#                     }
#
#                     if (!!content.data["application/javascript"]){
#                         try {
#                             eval(content.data["application/javascript"]);
#                         } catch(err) {
#                             curCell.output_area.handle_output.apply(curCell.output_area, arguments);
#                         }
#                         return;
#                     }
#
#                     if (html){
#                         try{
#                             getTargetNode().html(html);
#                         }catch(e){
#                             console.log("Invalid html output", e, html);
#                             getTargetNode().html( "Invalid html output: " + e.message + "<pre>"
#                                 + html.replace(/>/g,'&gt;').replace(/</g,'&lt;').replace(/"/g,'&quot;') + "<pre>");
#                         }
#
#                         if(curCell&&curCell.output_area&&curCell.output_area.outputs){
#                             setTimeout(function(){
#                                 var data = JSON.parse(JSON.stringify(content.data));
#                                 if(!!data["text/html"])data["text/html"]=html;
#                                 function savedData(data){
#
#                                     var markup='<style type="text/css">.pd_warning{display:none;}</style>';
#                                     markup+='<div class="pd_warning"><em>Hey, there\'s something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>';
#                                     nodes = $.parseHTML(data["text/html"], null, true);
#                                     var s = $(nodes).wrap("<div>").parent().find(".pd_save").not(".pd_save .pd_save")
#                                     s.each(function(){
#                                         var found = false;
#                                         if ( $(this).attr("id") ){
#                                             var n = $("#" + $(this).attr("id"));
#                                             if (n.length>0){
#                                                 found=true;
#                                                 n.each(function(){
#                                                     $(this).addClass("is-viewer-good");
#                                                 });
#                                                 markup+=n.wrap("<div>").parent().html();
#                                             }
#                                         }else{
#                                             $(this).addClass("is-viewer-good");
#                                         }
#                                         if (!found){
#                                             markup+=$(this).parent().html();
#                                         }
#                                     });
#                                     data["text/html"] = markup;
#                                     return data;
#                                 }
#                                 curCell.output_area.outputs.push({"data": savedData(data),"metadata":content.metadata,"output_type":msg_type});
#                             },2000);
#                         }
#                     }
#                 }else if (msg_type === "error") {
#                     require(['base/js/utils'], function(utils) {
#                         var tb = content.traceback;
#                         console.log("tb",tb);
#                         if (tb && tb.length>0){
#                             var data = tb.reduce(function(res, frame){return res+frame+'\\n';},"");
#                             console.log("data",data);
#                             data = utils.fixConsole(data);
#                             data = utils.fixCarriageReturn(data);
#                             data = utils.autoLinkUrls(data);
#                             getTargetNode().html("<pre>" + data +"</pre>");
#                         }
#                     });
#                 }
#
#                 //Append profiling info
#                 if (executionTime.length > 0 && $("#execution95b69afd").length == 0 ){
#                     getTargetNode().append(executionTime);
#                 }else if (startWallToWall && $("#execution95b69afd").length > 0 ){
#                     $("#execution95b69afd").append($("<div/>").text("Wall to Wall time: " + ( (new Date().getTime() - startWallToWall)/1000 ) + "s"));
#                 }
#
#                 if (typeof onDisplayDone95b69afd != "undefined"){
#                     onDisplayDone95b69afd();
#                 }
#                 $(document).trigger('pd_event', {type:"pd_load", targetNod
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style type="text/css" class="pd_save is-viewer-good">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#     height: inherit;
#     overflow: auto;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style><div class="df-table-wrapper df-table-wrapper-95b69afd panel-group pd_save is-viewer-good">
#   <!-- dataframe schema -->
#
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-95b69afd" data-parent="#df-table-wrapper-95b69afd">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-95b69afd" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>struct</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'Ticker', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'double', 'name': 'Quantity', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'Name', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'double', 'name': 'Last Close Price', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'long', 'name': 'Has Military', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'Environmental', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'double', 'name': 'Total Value', 'nullable': True}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-95b69afd" data-parent="#df-table-wrapper-95b69afd">Table</a>
#       </h4>
#     </div>
#
#     <div id="df-table-95b69afd" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input type="text" class="df-table-search form-control input-sm" placeholder="Search table">
#         <div>
#           <span class="df-table-search-count">Showing 60 of 60</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#
#               <div class="fixed-cell">Ticker</div>
#
#
#
#               <div class="fixed-cell">Quantity</div>
#
#
#
#               <div class="fixed-cell">Name</div>
#
#
#
#               <div class="fixed-cell">Last Close Price</div>
#
#
#
#               <div class="fixed-cell">Has Military</div>
#
#
#
#               <div class="fixed-cell">Environmental</div>
#
#
#
#               <div class="fixed-cell">Total Value</div>
#
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#
#                 <th><div>Ticker</div></th>
#
#
#
#                 <th><div>Quantity</div></th>
#
#
#
#                 <th><div>Name</div></th>
#
#
#
#                 <th><div>Last Close Price</div></th>
#
#
#
#                 <th><div>Has Military</div></th>
#
#
#
#                 <th><div>Environmental</div></th>
#
#
#
#                 <th><div>Total Value</div></th>
#
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#
#                 <td>FBCVX</td>
#
#
#
#                 <td>8.52802862477</td>
#
#
#
#                 <td>Fidelity Blue Chip Value Fund </td>
#
#
#
#                 <td>18.76</td>
#
#
#
#                 <td>0</td>
#
#
#
#                 <td>High</td>
#
#
#
#                 <td>159.985817001</td>
#
#
#               </tr>
#
#               <tr>
#
#
#                 <td>FLPSX</td>
#
#
#
#                 <td>4.19366728603</td>
#
#
#
#                 <td>Fidelity Low-Priced Stock Fund </td>
#
#
#
#                 <td>54.09</td>
#
#
#
#                 <td>0</td>
#
#
#
#                 <td>High</td>
#
#
#
#                 <td>226.835463501</td>

# %% [markdown]
# ## How close did we match the risk of the benchmark?

# %%
print("The difference in variance between the benchmark and the optimized portfolio is: ")
print("%.8f" % json.loads(r.text)["Metadata"]["ObjectiveValue"])
# Out:
# The difference in variance between the benchmark and the optimized portfolio is:
# 0.00000165

# %% [markdown]
# ## Checking that the constraints are met:

# %%
#Sum up quantity * price
portfolio_value = 0
for j in new_portfolio:
    portfolio_value += j[-1]
print("Total Portfolio Value: " + str(portfolio_value))

#We used a Spark Data frame to display the results nicely above. Now we convert it back to a pandas dataframe to do our aggregation analysis:
OptimizedPortfolio = d1.toPandas()
for f in fields[4:-1]:
    print("Aggregation: " + f)
    elements = set(OptimizedPortfolio[f])
    for e in elements:
        aggr = OptimizedPortfolio.filter(items=fields)[OptimizedPortfolio[f] == e]
        aggr_pct = aggr["Total Value"].sum() / portfolio_value
        print("  Total allocation to " + str(e) + " is " + str(aggr_pct*100) + "%.")
# Out:
# Total Portfolio Value: 42118.1084206
# Aggregation: Has Military
#   Total allocation to 0 is 100.0%.
# Aggregation: Environmental
#   Total allocation to High is 49.9773398728%.
#   Total allocation to Average is 10.4686954441%.
#   Total allocation to Low is 39.5539646831%.
